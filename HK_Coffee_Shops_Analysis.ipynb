# %% [markdown]
# <a href="https://colab.research.google.com/github/vickyzai/hk-specialty-cofee-shops/blob/main/HK_Coffee_Shops_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import time
import re
import geopandas
from shapely.geometry import Point
import folium

#Step 1: The quest for the data

# --- Configuration ---
API_KEY = 'AIzaSyC_OxTIl1FHPWFUnBOnm7nx5jYqJIcyk1o' # <--- REPLACE THIS WITH YOUR ACTUAL GOOGLE PLACES API KEY!
BASE_URL = 'https://maps.googleapis.com/maps/api/place/textsearch/json?'

# List of Hong Kong's 18 Districts
hong_kong_districts = [
    # Hong Kong Island
    "Central and Western District, Hong Kong Island, Hong Kong",
    "Eastern District, Hong Kong Island, Hong Kong",
    "Southern District, Hong Kong Island, Hong Kong",
    "Wan Chai District, Hong Kong Island, Hong Kong",
    # Kowloon
    "Kowloon City District, Kowloon, Hong Kong",
    "Kwun Tong District, Kowloon, Hong Kong",
    "Sham Shui Po District, Kowloon, Hong Kong",
    "Wong Tai Sin District, Kowloon, Hong Kong",
    "Yau Tsim Mong District, Kowloon, Hong Kong",
    # New Territories
    "Islands District, New Territories, Hong Kong",
    "Kwai Tsing District, New Territories, Hong Kong",
    "North District, New Territories, Hong Kong",
    "Sai Kung District, New Territories, Hong Kong",
    "Sha Tin District, New Territories, Hong Kong",
    "Tai Po District, New Territories, Hong Kong",
    "Tsuen Wan District, New Territories, Hong Kong",
    "Tuen Mun District, New Territories, Hong Kong",
    "Yuen Long District, New Territories, Hong Kong"
]

# List of common coffee chain names to filter out (case-insensitive)
CHAIN_NAMES_TO_EXCLUDE = [
    'Starbucks', 'Pacific Coffee', 'McCafé',
    'Pret A Manger', '% Arabica','The Coffee Academïcs',
    'Nespresso', 'Habitu'
]

# Hong Kong Bounding Box Coordinates (approximate)
HK_MIN_LAT = 22.15
HK_MAX_LAT = 22.56
HK_MIN_LON = 113.82
HK_MAX_LON = 114.45

# List to store all collected coffee shop data from all districts
all_coffee_shops_raw = []

# --- Function to fetch data from Google Places API ---
def fetch_places(query, api_key, pagetoken=None):
    """
    Fetches places data from Google Places API using a text search.
    Handles pagination using 'pagetoken'.
    """
    params = {
        'query': query,
        'key': api_key,
        'language': 'en'
    }
    if pagetoken:
        params['pagetoken'] = pagetoken

    response = requests.get(BASE_URL, params=params)
    results = response.json()

    if results.get('status') == 'ZERO_RESULTS':
        return [], None
    elif results.get('status') != 'OK':
        print(f"API Error for query '{query}': {results.get('status')} - {results.get('error_message', 'No error message provided.')}")
        return None, None

    return results.get('results'), results.get('next_page_token')

# --- Main data collection loop for all districts ---
print("Starting comprehensive search for coffee shops across all 18 districts of Hong Kong...")

for district in hong_kong_districts:
    current_search_query = f'coffee shop in {district}'
    next_page_token = None
    page_count = 0

    print(f"\n--- Searching in: {district} ---")

    while True:
        page_count += 1
        print(f"  Fetching page {page_count} for {district}...")

        results, next_page_token = fetch_places(current_search_query, API_KEY, next_page_token)

        if results is None:
            print(f"  Stopped fetching for {district} due to an API error.")
            break
        elif not results:
            print(f"  No more results found for {district} (or reached end of Text Search limit for this query).")
            break

        for place in results:
            name = place.get('name')
            address = place.get('formatted_address')
            latitude = place['geometry']['location']['lat']
            longitude = place['geometry']['location']['lng']
            rating = place.get('rating')
            user_ratings_total = place.get('user_ratings_total')
            place_id = place.get('place_id')

            all_coffee_shops_raw.append({
                'Name': name,
                'Address': address,
                'Latitude': latitude,
                'Longitude': longitude,
                'Rating': rating,
                'Total Reviews': user_ratings_total,
                'Place ID': place_id,
                'District_Queried': district
            })

        if next_page_token:
            time.sleep(2)
        else:
            break

# --- Process and Consolidate Data ---
if all_coffee_shops_raw:
    df_raw = pd.DataFrame(all_coffee_shops_raw)

    # Remove duplicates based on 'Place ID'
    df_unique = df_raw.drop_duplicates(subset=['Place ID'], keep='first').copy()

    # Filter by Hong Kong Bounding Box
    print(f"\nTotal unique shops before bounding box filter: {len(df_unique)}")
    df_hk_only = df_unique[
        (df_unique['Latitude'] >= HK_MIN_LAT) & (df_unique['Latitude'] <= HK_MAX_LAT) &
        (df_unique['Longitude'] >= HK_MIN_LON) & (df_unique['Longitude'] <= HK_MAX_LON)
    ].copy()
    print(f"Total shops after bounding box filter (Hong Kong only): {len(df_hk_only)}")

    # Filter out chain stores
    print(f"Total HK-only shops before chain filter: {len(df_hk_only)}")
    chain_pattern = '|'.join([re.escape(name) for name in CHAIN_NAMES_TO_EXCLUDE])
    df_specialty = df_hk_only[~df_hk_only['Name'].str.contains(chain_pattern, case=False, na=False)].copy()
    print(f"Total specialty coffee shops (after chain filter): {len(df_specialty)}")

    # Load District Boundary Data and Perform Spatial Join
    HK_DISTRICTS_GEOJSON_URL = 'hksar_18_district_boundary.json'
    print(f"\nLoading Hong Kong district boundaries from: {HK_DISTRICTS_GEOJSON_URL}")
    try:
        gdf_districts = geopandas.read_file(HK_DISTRICTS_GEOJSON_URL)
        gdf_districts = gdf_districts[['geometry', 'District']]
        print(f"Successfully loaded {len(gdf_districts)} district polygons.")
    except Exception as e:
        print(f"Error loading district GeoJSON: {e}")
        print("Please ensure 'HAD_18_Districts.json' (or your file name) is uploaded to Colab's Files tab.")
        gdf_districts = None # Set to None if loading fails

    if gdf_districts is not None:
        df_specialty_gdf = geopandas.GeoDataFrame(
            df_specialty,
            geometry=geopandas.points_from_xy(df_specialty.Longitude, df_specialty.Latitude),
            crs="EPSG:4326"
        )

        print("\nPerforming spatial join to assign accurate districts to coffee shops...")
        df_final = geopandas.sjoin(
            df_specialty_gdf,
            gdf_districts,
            how="left",
            predicate="within"
        )

        df_final.rename(columns={'District': 'Actual_District_from_Spatial_Join'}, inplace=True)
        df_final['Actual_District_from_Spatial_Join'] = df_final['Actual_District_from_Spatial_Join'].fillna('Unknown/Outside Boundary')

        df_final.drop(columns=['index_right'], inplace=True)

        print("\nSpatial join complete. Preview of data with accurate district:")
        print(df_final[['Name', 'District_Queried', 'Actual_District_from_Spatial_Join', 'Rating', 'Total Reviews']].head())
    else:
        print("Skipping spatial join due to GeoJSON loading error. Output will not have accurate district assignments.")
        df_final = df_specialty.copy()
        df_final['Actual_District_from_Spatial_Join'] = 'Spatial Join Failed'

#### to delete
    # --- Calculate Bayesian Average (apply to the final DataFrame) ---
    df_final['Rating'] = pd.to_numeric(df_final['Rating'], errors='coerce').fillna(df_final['Rating'].mean())
    df_final['Total Reviews'] = pd.to_numeric(df_final['Total Reviews'], errors='coerce').fillna(0).astype(int)

    C = df_final['Rating'].mean()
    m = 100 # Bayesian 'm' value
    print(f"\nCalculating Bayesian Average with m = {m}")
    df_final['Bayesian_Weighted_Rating'] = df_final.apply(lambda row: (row['Total Reviews'] * row['Rating'] + m * C) / (row['Total Reviews'] + m) if row['Total Reviews'] > 0 else C, axis=1)
### to delete

    output_filename = 'hong_kong_specialty_coffee_shops_final.csv'
    if 'geometry' in df_final.columns:
        df_final.drop(columns=['geometry'], inplace=True)

    df_final.to_csv(output_filename, index=False, encoding='utf-8')

    print(f"\n--- Data Collection and Filtering Complete ---")
    print(f"Final number of specialty coffee shops in Hong Kong: {len(df_final)}")
    print(f"Data saved to {output_filename}")
    print("\nHere's a preview of the final, filtered data:")
    print(df_final.head())
# Out:
# Starting comprehensive search for coffee shops across all 18 districts of Hong Kong...
#
# --- Searching in: Central and Western District, Hong Kong Island, Hong Kong ---
#   Fetching page 1 for Central and Western District, Hong Kong Island, Hong Kong...
#   Fetching page 2 for Central and Western District, Hong Kong Island, Hong Kong...
#   Fetching page 3 for Central and Western District, Hong Kong Island, Hong Kong...
#
# --- Searching in: Eastern District, Hong Kong Island, Hong Kong ---
#   Fetching page 1 for Eastern District, Hong Kong Island, Hong Kong...
#   Fetching page 2 for Eastern District, Hong Kong Island, Hong Kong...
#   Fetching page 3 for Eastern District, Hong Kong Island, Hong Kong...
#
# --- Searching in: Southern District, Hong Kong Island, Hong Kong ---
#   Fetching page 1 for Southern District, Hong Kong Island, Hong Kong...
#   Fetching page 2 for Southern District, Hong Kong Island, Hong Kong...
#   Fetching page 3 for Southern District, Hong Kong Island, Hong Kong...
#
# --- Searching in: Wan Chai District, Hong Kong Island, Hong Kong ---
#   Fetching page 1 for Wan Chai District, Hong Kong Island, Hong Kong...
#   Fetching page 2 for Wan Chai District, Hong Kong Island, Hong Kong...
#   Fetching page 3 for Wan Chai District, Hong Kong Island, Hong Kong...
#
# --- Searching in: Kowloon City District, Kowloon, Hong Kong ---
#   Fetching page 1 for Kowloon City District, Kowloon, Hong Kong...
#   Fetching page 2 for Kowloon City District, Kowloon, Hong Kong...
#   Fetching page 3 for Kowloon City District, Kowloon, Hong Kong...
#
# --- Searching in: Kwun Tong District, Kowloon, Hong Kong ---
#   Fetching page 1 for Kwun Tong District, Kowloon, Hong Kong...
#   Fetching page 2 for Kwun Tong District, Kowloon, Hong Kong...
#   Fetching page 3 for Kwun Tong District, Kowloon, Hong Kong...
#
# --- Searching in: Sham Shui Po District, Kowloon, Hong Kong ---
#   Fetching page 1 for Sham Shui Po District, Kowloon, Hong Kong...
#   Fetching page 2 for Sham Shui Po District, Kowloon, Hong Kong...
#   Fetching page 3 for Sham Shui Po District, Kowloon, Hong Kong...
#
# --- Searching in: Wong Tai Sin District, Kowloon, Hong Kong ---
#   Fetching page 1 for Wong Tai Sin District, Kowloon, Hong Kong...
#   Fetching page 2 for Wong Tai Sin District, Kowloon, Hong Kong...
#   Fetching page 3 for Wong Tai Sin District, Kowloon, Hong Kong...
#
# --- Searching in: Yau Tsim Mong District, Kowloon, Hong Kong ---
#   Fetching page 1 for Yau Tsim Mong District, Kowloon, Hong Kong...
#   Fetching page 2 for Yau Tsim Mong District, Kowloon, Hong Kong...
#   Fetching page 3 for Yau Tsim Mong District, Kowloon, Hong Kong...
#
# --- Searching in: Islands District, New Territories, Hong Kong ---
#   Fetching page 1 for Islands District, New Territories, Hong Kong...
#   Fetching page 2 for Islands District, New Territories, Hong Kong...
#   Fetching page 3 for Islands District, New Territories, Hong Kong...
#
# --- Searching in: Kwai Tsing District, New Territories, Hong Kong ---
#   Fetching page 1 for Kwai Tsing District, New Territories, Hong Kong...
#   Fetching page 2 for Kwai Tsing District, New Territories, Hong Kong...
#   Fetching page 3 for Kwai Tsing District, New Territories, Hong Kong...
#
# --- Searching in: North District, New Territories, Hong Kong ---
#   Fetching page 1 for North District, New Territories, Hong Kong...
#   Fetching page 2 for North District, New Territories, Hong Kong...
#   Fetching page 3 for North District, New Territories, Hong Kong...
#
# --- Searching in: Sai Kung District, New Territories, Hong Kong ---
#   Fetching page 1 for Sai Kung District, New Territories, Hong Kong...
#   Fetching page 2 for Sai Kung District, New Territories, Hong Kong...
#   Fetching page 3 for Sai Kung District, New Territories, Hong Kong...
#
# --- Searching in: Sha Tin District, New Territories, Hong Kong ---
#   Fetching page 1 for Sha Tin District, New Territories, Hong Kong...
#   Fetching page 2 for Sha Tin District, New Territories, Hong Kong...
#   Fetching page 3 for Sha Tin District, New Territories, Hong Kong...
#
# --- Searching in: Tai Po District, New Territories, Hong Kong ---
#   Fetching page 1 for Tai Po District, New Territories, Hong Kong...
#   Fetching page 2 for Tai Po District, New Territories, Hong Kong...
#   Fetching page 3 for Tai Po District, New Territories, Hong Kong...
#
# --- Searching in: Tsuen Wan District, New Territories, Hong Kong ---
#   Fetching page 1 for Tsuen Wan District, New Territories, Hong Kong...
#   Fetching page 2 for Tsuen Wan District, New Territories, Hong Kong...
#   Fetching page 3 for Tsuen Wan District, New Territories, Hong Kong...
#
# --- Searching in: Tuen Mun District, New Territories, Hong Kong ---
#   Fetching page 1 for Tuen Mun District, New Territories, Hong Kong...
#   Fetching page 2 for Tuen Mun District, New Territories, Hong Kong...
#   Fetching page 3 for Tuen Mun District, New Territories, Hong Kong...
#
# --- Searching in: Yuen Long District, New Territories, Hong Kong ---
#   Fetching page 1 for Yuen Long District, New Territories, Hong Kong...
#   Fetching page 2 for Yuen Long District, New Territories, Hong Kong...
#   Fetching page 3 for Yuen Long District, New Territories, Hong Kong...
#
# Total unique shops before bounding box filter: 830
# Total shops after bounding box filter (Hong Kong only): 830
# Total HK-only shops before chain filter: 830
# Total specialty coffee shops (after chain filter): 730
#
# Loading Hong Kong district boundaries from: hksar_18_district_boundary.json
# Successfully loaded 18 district polygons.
#
# Performing spatial join to assign accurate districts to coffee shops...
#
# Spatial join complete. Preview of data with accurate district:
#                               Name  \
# 0                      Nook Coffee
# 1        Urban Coffee Roaster SOHO
# 2  Hazel & Hershey Coffee Roasters
# 3    Chart Coffee (Central Market)
# 4            Two-and-a-Half Street
#
#                                     District_Queried  \
# 0  Central and Western District, Hong Kong Island...
# 1  Central and Western District, Hong Kong Island...
# 2  Central and Western District, Hong Kong Island...
# 3  Central and Western District, Hong Kong Island...
# 4  Central and Western District, Hong Kong Island...
#
#   Actual_District_from_Spatial_Join  Rating  Total Reviews
# 0                 Central & Western     4.9           80.0
# 1                 Central & Western     4.6          148.0
# 2                 Central & Western     4.2          474.0
# 3                 Central & Western     4.8          440.0
# 4                 Central & Western     4.7          195.0
#
# Calculating Bayesian Average with m = 100
#
# --- Data Collection and Filtering Complete ---
# Final number of specialty coffee shops in Hong Kong: 730
# Data saved to hong_kong_specialty_coffee_shops_final_filtered_v3.csv
#
# Here's a preview of the final, filtered data:
#                               Name  \
# 0                      Nook Coffee
# 1        Urban Coffee Roaster SOHO
# 2  Hazel & Hershey Coffee Roasters
# 3    Chart Coffee (Central Market)
# 4            Two-and-a-Half Street
#
#                                              Address   Latitude   Longitude  \
# 0   Sheung Wan, 9 Mee Lun Street, Central, Hong Kong  22.284065  114.152464
# 1  35 and 37, C Wisdom Centre, UG/F and 1/F, Holl...  22.282252  114.153599
# 2             Shop 3, 69 Peel St, Central, Hong Kong  22.282153  114.151969
# 3  Shop 218, 2/F, Central Market, 93 Queen's Road...  22.283944  114.155548
# 4                1 David Ln, Sai Ying Pun, Hong Kong  22.285945  114.142024
#
#    Rating  Total Reviews                     Place ID  \
# 0     4.9             80  ChIJM2BArloBBDQRDNqSk1RPRXw
# 1     4.6            148  ChIJtyL2liIBBDQRgDPU3kxFLHo
# 2     4.2            474  ChIJWwKCvHsABDQRuS8cvcaIUDg
# 3     4.8            440  ChIJ4-6wtZgBBDQRkUhC8o89pPw
# 4     4.7            195  ChIJm2DZWCr_AzQRw3Ly0bPF7bQ
#
#                                     District_Queried  \
# 0  Central and Western District, Hong Kong Island...
# 1  Central and Western District, Hong Kong Island...
# 2  Central and Western District, Hong Kong Island...
# 3  Central and Western District, Hong Kong Island...
# 4  Central and Western District, Hong Kong Island...
#
#   Actual_District_from_Spatial_Join  Bayesian_Weighted_Rating
# 0                 Central & Western                  4.516041
# 1                 Central & Western                  4.442288
# 2                 Central & Western                  4.201546
# 3                 Central & Western                  4.690532
# 4                 Central & Western                  4.533516
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-81ce45f984f7> in <cell line: 0>()
#     234         ).add_to(m)
#     235
# --> 236         marker_cluster = MarkerCluster().add_to(m)
#     237
#     238         print("\nAdding coffee shop markers to the map with corrected districts...")
#
# NameError: name 'MarkerCluster' is not defined

# %%
import pandas as pd

# Step 3: Brewing a Fair Ranking - The Bayesian Average
df_coffeeshops = pd.read_csv('hong_kong_coffee_shops_comprehensive.csv')

# Bayesian Average
# Calculate C (mean rating of all specialty coffee shops)
C = df_coffeeshops['Rating'].mean()
print(f"Overall average rating (C): {C:.2f}")

# Define m (minimum reviews threshold)
m = 100

# Apply the Bayesian Average formula
def bayesian_average(row, C, m):
    v = row['Total Reviews']
    R = row['Rating']
    return (v * R + m * C) / (v + m)

df_coffeeshops['Bayesian_Weighted_Rating'] = df_coffeeshops.apply(bayesian_average, axis=1, C=C, m=m)

print(f"\nTop 10 Coffee Shops by Bayesian Weighted Rating (m={m}):")
print(df_coffeeshops[['Name', 'Rating', 'Total Reviews', 'Bayesian_Weighted_Rating']].sort_values(by='Bayesian_Weighted_Rating', ascending=False).head(10))
print("\n---")

# Optional: Export the updated DataFrame with new scores ---
output_filename_with_scores = 'hong_kong_specialty_coffee_shops_with_scores.csv'
df_coffeeshops.to_csv(output_filename_with_scores, index=False, encoding='utf-8')
print(f"\nData with new scores saved to {output_filename_with_scores}")
# Out:
# Original Data Head (with filled NaNs):
#                               Name  Rating  Total Reviews
# 0    Chart Coffee (Central Market)     4.8            440
# 1  Hazel & Hershey Coffee Roasters     4.2            474
# 2                      Nook Coffee     4.9             79
# 3                   Halfway Coffee     4.5           1082
# 4       Islet Coffee Lab (Central)     4.8             65
#
# ---
# Overall average rating (C): 4.15
#
# Top 10 Coffee Shops by Bayesian Weighted Rating (m=100):
#                                         Name  Rating  Total Reviews  \
# 63   Happy Kitchen Cafe & Bar by German Pool     4.9            841
# 439  sensory ZERO [ Kwai Chung | The Field ]     5.0            355
# 0              Chart Coffee (Central Market)     4.8            440
# 684                   Nekos Cube 方塊貓 | 貓cafe     4.9            217
# 596                      Quality Life Coffee     4.9            136
# 104                      Black Cherry Coffee     4.8            180
# 438                       Chart Coffee (KCC)     5.0             91
# 51                    The Missing Piece Cafe     4.7            270
# 411                 Island Table Grocer Cafe     4.7            263
# 542                      Hookee Dessert Shop     4.9            112
#
#      Bayesian_Weighted_Rating
# 63                   4.820208
# 439                  4.813001
# 0                    4.679473
# 684                  4.663141
# 596                  4.581846
# 104                  4.567556
# 438                  4.554532
# 51                   4.551123
# 411                  4.548253
# 542                  4.545829
#
# ---
#
# Data with new scores saved to hong_kong_specialty_coffee_shops_with_scores.csv

# %%
# Step 4: The Map Unfolds - Visualizing Hong Kong's Coffee Landscape
# Top 10 Coffee Shops and Average Rating by District

import pandas as pd
import folium
from folium.plugins import MarkerCluster
import numpy as np # For handling potential NaN values in rating/reviews
import re # For the chain filtering if you reload comprehensive data

input_filename = 'hong_kong_coffee_shops_final.csv'


# Load Data
try:
    df_coffeeshops = pd.read_csv(input_filename)
    print(f"Successfully loaded {len(df_coffeeshops)} coffee shops from {input_filename}")
except FileNotFoundError:
    print(f"Error: {input_filename} not found. Please make sure the CSV file is in the correct directory.")
    print("If you just ran the data collection code, remember to download the CSV from Colab's Files tab and then upload it, or run the full data collection script first.")
    # Exit or handle gracefully if file not found
    exit()


# Generate Top 10 Coffee Shops
print("\n--- Top 10 Specialty Coffee Shops by Bayesian Weighted Rating) ---")
top_10_shops = df_coffeeshops.sort_values(by='Bayesian_Weighted_Rating', ascending=False).head(10)
# Select only relevant columns for display
top_10_display = top_10_shops[['Name', 'Actual_District_from_Spatial_Join', 'Rating', 'Total Reviews', 'Bayesian_Weighted_Rating']]
top_10_display['Bayesian_Weighted_Rating'] = top_10_display['Bayesian_Weighted_Rating'].round(2)
print(top_10_display.to_string(index=False)) # .to_string() for better console formatting

# Styling the Top 10 Table
styled_top_10_table = top_10_display.style \
    .background_gradient(subset=['Bayesian_Weighted_Rating'], cmap='Blues') \
    .format({
        'Rating': "{:.2f}",
        'Total Reviews': "{:,.0f}", # Format as integer with comma separator
        'Bayesian_Weighted_Rating': "{:.2f}"
    }) \
    .set_caption("Top 10 Specialty Coffee Shops in Hong Kong") \
    .set_properties(**{'font-size': '11pt', 'text-align': 'center'})

# Display the styled table
display(styled_top_10_table)


# Calculate Average Scores by District
print("\n--- Average Bayesian Score and Total Shops by District ---")
# Ensure 'Actual_District_from_Spatial_Join' exists and is used for grouping
if 'Actual_District_from_Spatial_Join' in df_coffeeshops.columns:
    avg_scores_by_district = df_coffeeshops.groupby('Actual_District_from_Spatial_Join').agg(
        Average_Bayesian_Score=('Bayesian_Weighted_Rating', 'mean'), # Calculate mean of Bayesian score
        Average_Rating=('Rating', 'mean'), # Calculate mean of rating
        Number_Of_Coffee_Shops=('Name', 'count'), # Count the number of shops (using 'Name' column as a proxy for rows)
        Average_Total_Reviews=('Total Reviews', lambda x: round(x.mean())) # Calculate mean of Total Reviews for context
    ).sort_values(by='Average_Bayesian_Score', ascending=False) # Sort by the average Bayesian score

    avg_scores_by_district = avg_scores_by_district.round(2) #round to 2 decimal places


# Styling the District Averages Table
    styled_district_table = avg_scores_by_district.style \
        .background_gradient(subset=['Average_Bayesian_Score'], cmap='Blues') \
        .background_gradient(subset=['Average_Rating'], cmap='Blues') \
        .format({
            'Average_Bayesian_Score': "{:.2f}",
            'Average_Rating': "{:.2f}",
            'Number_Of_Coffee_Shops': "{:,.0f}",
            'Average_Total_Reviews': "{:,.0f}"
        }) \
        .set_caption("Average Coffee Shop Performance by District") \
        .set_properties(**{'font-size': '11pt', 'text-align': 'center'})

    # Display the styled table
    display(styled_district_table)
# Out:
# Successfully loaded 563 coffee shops from hong_kong_coffee_shops_final.csv
#
# --- Top 10 Specialty Coffee Shops by Bayesian Weighted Rating) ---
#                          Name Actual_District_from_Spatial_Join  Rating  Total Reviews  Bayesian_Weighted_Rating
# Chart Coffee (Central Market)                 Central & Western     4.8            440                      4.69
#            Chart Coffee (KCC)                        Kwai Tsing     5.0             93                      4.59
#           Black Cherry Coffee                          Southern     4.8            180                      4.59
#        The Missing Piece Cafe                 Central & Western     4.7            271                      4.57
#                Halfway Coffee                 Central & Western     4.6           1086                      4.57
#      Island Table Grocer Cafe                           Islands     4.7            263                      4.56
#    Blend & Grind Kennedy Town                 Central & Western     4.6            685                      4.55
#                 HIKARI Coffee                         Tsuen Wan     4.6            615                      4.55
#      Blend & Grind Mid-Levels                 Central & Western     4.6            491                      4.53
#           Good Day Coffee Co.                     Yau Tsim Mong     4.8            122                      4.53
# /tmp/ipython-input-4-1690758510.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_display['Bayesian_Weighted_Rating'] = top_10_display['Bayesian_Weighted_Rating'].round(2)
# <style type="text/css">
# #T_196d3_row0_col0, #T_196d3_row0_col1, #T_196d3_row0_col2, #T_196d3_row0_col3, #T_196d3_row1_col0, #T_196d3_row1_col1, #T_196d3_row1_col2, #T_196d3_row1_col3, #T_196d3_row2_col0, #T_196d3_row2_col1, #T_196d3_row2_col2, #T_196d3_row2_col3, #T_196d3_row3_col0, #T_196d3_row3_col1, #T_196d3_row3_col2, #T_196d3_row3_col3, #T_196d3_row4_col0, #T_196d3_row4_col1, #T_196d3_row4_col2, #T_196d3_row4_col3, #T_196d3_row5_col0, #T_196d3_row5_col1, #T_196d3_row5_col2, #T_196d3_row5_col3, #T_196d3_row6_col0, #T_196d3_row6_col1, #T_196d3_row6_col2, #T_196d3_row6_col3, #T_196d3_row7_col0, #T_196d3_row7_col1, #T_196d3_row7_col2, #T_196d3_row7_col3, #T_196d3_row8_col0, #T_196d3_row8_col1, #T_196d3_row8_col2, #T_196d3_row8_col3, #T_196d3_row9_col0, #T_196d3_row9_col1, #T_196d3_row9_col2, #T_196d3_row9_col3 {
#   font-size: 11pt;
#   text-align: center;
# }
# #T_196d3_row0_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_196d3_row1_col4, #T_196d3_row2_col4 {
#   background-color: #9fcae1;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_196d3_row3_col4, #T_196d3_row4_col4 {
#   background-color: #c6dbef;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_196d3_row5_col4 {
#   background-color: #d3e3f3;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_196d3_row6_col4, #T_196d3_row7_col4 {
#   background-color: #dfebf7;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_196d3_row8_col4, #T_196d3_row9_col4 {
#   background-color: #f7fbff;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# </style>
# <table id="T_196d3" class="dataframe">
#   <caption>Top 10 Specialty Coffee Shops in Hong Kong</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_196d3_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_196d3_level0_col1" class="col_heading level0 col1" >Actual_District_from_Spatial_Join</th>
#       <th id="T_196d3_level0_col2" class="col_heading level0 col2" >Rating</th>
#       <th id="T_196d3_level0_col3" class="col_heading level0 col3" >Total Reviews</th>
#       <th id="T_196d3_level0_col4" class="col_heading level0 col4" >Bayesian_Weighted_Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_196d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_196d3_row0_col0" class="data row0 col0" >Chart Coffee (Central Market)</td>
#       <td id="T_196d3_row0_col1" class="data row0 col1" >Central & Western</td>
#       <td id="T_196d3_row0_col2" class="data row0 col2" >4.80</td>
#       <td id="T_196d3_row0_col3" class="data row0 col3" >440</td>
#       <td id="T_196d3_row0_col4" class="data row0 col4" >4.69</td>
#     </tr>
#     <tr>
#       <th id="T_196d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_196d3_row1_col0" class="data row1 col0" >Chart Coffee (KCC)</td>
#       <td id="T_196d3_row1_col1" class="data row1 col1" >Kwai Tsing</td>
#       <td id="T_196d3_row1_col2" class="data row1 col2" >5.00</td>
#       <td id="T_196d3_row1_col3" class="data row1 col3" >93</td>
#       <td id="T_196d3_row1_col4" class="data row1 col4" >4.59</td>
#     </tr>
#     <tr>
#       <th id="T_196d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_196d3_row2_col0" class="data row2 col0" >Black Cherry Coffee</td>
#       <td id="T_196d3_row2_col1" class="data row2 col1" >Southern</td>
#       <td id="T_196d3_row2_col2" class="data row2 col2" >4.80</td>
#       <td id="T_196d3_row2_col3" class="data row2 col3" >180</td>
#       <td id="T_196d3_row2_col4" class="data row2 col4" >4.59</td>
#     </tr>
#     <tr>
#       <th id="T_196d3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_196d3_row3_col0" class="data row3 col0" >The Missing Piece Cafe</td>
#       <td id="T_196d3_row3_col1" class="data row3 col1" >Central & Western</td>
#       <td id="T_196d3_row3_col2" class="data row3 col2" >4.70</td>
#       <td id="T_196d3_row3_col3" class="data row3 col3" >271</td>
#       <td id="T_196d3_row3_col4" class="data row3 col4" >4.57</td>
#     </tr>
#     <tr>
#       <th id="T_196d3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_196d3_row4_col0" class="data row4 col0" >Halfway Coffee</td>
#       <td id="T_196d3_row4_col1" class="data row4 col1" >Central & Western</td>
#       <td id="T_196d3_row4_col2" class="data row4 col2" >4.60</td>
#       <td id="T_196d3_row4_col3" class="data row4 col3" >1,086</td>
#       <td id="T_196d3_row4_col4" class="data row4 col4" >4.57</td>
#     </tr>
#     <tr>
#       <th id="T_196d3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_196d3_row5_col0" class="data row5 col0" >Island Table Grocer Cafe</td>
#       <td id="T_196d3_row5_col1" class="data row5 col1" >Islands</td>
#       <td id="T_196d3_row5_col2" class="data row5 col2" >4.70</td>
#       <td id="T_196d3_row5_col3" class="data row5 col3" >263</td>
#       <td id="T_196d3_row5_col4" class="data row5 col4" >4.56</td>
#     </tr>
#     <tr>
#       <th id="T_196d3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_196d3_row6_col0" class="data row6 col0" >Blend & Grind Kennedy Town</td>
#       <td id="T_196d3_row6_col1" class="data row6 col1" >Central & Western</td>
#       <td id="T_196d3_row6_col2" class="data row6 col2" >4.60</td>
#       <td id="T_196d3_row6_col3" class="data row6 col3" >685</td>
#       <td id="T_196d3_row6_col4" class="data row6 col4" >4.55</td>
#     </tr>
#     <tr>
#       <th id="T_196d3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_196d3_row7_col0" class="data row7 col0" >HIKARI Coffee</td>
#       <td id="T_196d3_row7_col1" class="data row7 col1" >Tsuen Wan</td>
#       <td id="T_196d3_row7_col2" class="data row7 col2" >4.60</td>
#       <td id="T_196d3_row7_col3" class="data row7 col3" >615</td>
#       <td id="T_196d3_row7_col4" class="data row7 col4" >4.55</td>
#     </tr>
#     <tr>
#       <th id="T_196d3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_196d3_row8_col0" class="data row8 col0" >Blend & Grind Mid-Levels</td>
#       <td id="T_196d3_row8_col1" class="data row8 col1" >Central & Western</td>
#       <td id="T_196d3_row8_col2" class="data row8 col2" >4.60</td>
#       <td id="T_196d3_row8_col3" class="data row8 col3" >491</td>
#       <td id="T_196d3_row8_col4" class="data row8 col4" >4.53</td>
#     </tr>
#     <tr>
#       <th id="T_196d3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_196d3_row9_col0" class="data row9 col0" >Good Day Coffee Co.</td>
#       <td id="T_196d3_row9_col1" class="data row9 col1" >Yau Tsim Mong</td>
#       <td id="T_196d3_row9_col2" class="data row9 col2" >4.80</td>
#       <td id="T_196d3_row9_col3" class="data row9 col3" >122</td>
#       <td id="T_196d3_row9_col4" class="data row9 col4" >4.53</td>
#     </tr>
#   </tbody>
# </table>
# --- Average Bayesian Score and Total Shops by District ---
# <style type="text/css">
# #T_ba5ef_row0_col0, #T_ba5ef_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row0_col2, #T_ba5ef_row0_col3, #T_ba5ef_row1_col2, #T_ba5ef_row1_col3, #T_ba5ef_row2_col2, #T_ba5ef_row2_col3, #T_ba5ef_row3_col2, #T_ba5ef_row3_col3, #T_ba5ef_row4_col2, #T_ba5ef_row4_col3, #T_ba5ef_row5_col2, #T_ba5ef_row5_col3, #T_ba5ef_row6_col2, #T_ba5ef_row6_col3, #T_ba5ef_row7_col2, #T_ba5ef_row7_col3, #T_ba5ef_row8_col2, #T_ba5ef_row8_col3, #T_ba5ef_row9_col2, #T_ba5ef_row9_col3, #T_ba5ef_row10_col2, #T_ba5ef_row10_col3, #T_ba5ef_row11_col2, #T_ba5ef_row11_col3, #T_ba5ef_row12_col2, #T_ba5ef_row12_col3, #T_ba5ef_row13_col2, #T_ba5ef_row13_col3, #T_ba5ef_row14_col2, #T_ba5ef_row14_col3, #T_ba5ef_row15_col2, #T_ba5ef_row15_col3, #T_ba5ef_row16_col2, #T_ba5ef_row16_col3, #T_ba5ef_row17_col2, #T_ba5ef_row17_col3 {
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row1_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row1_col1, #T_ba5ef_row10_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row2_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row2_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row3_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row3_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row4_col0 {
#   background-color: #8fc2de;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row4_col1 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row5_col0, #T_ba5ef_row6_col0, #T_ba5ef_row7_col0, #T_ba5ef_row8_col0 {
#   background-color: #a8cee4;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row5_col1 {
#   background-color: #7ab6d9;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row6_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row7_col1 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row8_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row9_col0, #T_ba5ef_row10_col0 {
#   background-color: #b3d3e8;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row9_col1, #T_ba5ef_row14_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row11_col0, #T_ba5ef_row12_col0, #T_ba5ef_row13_col0 {
#   background-color: #bed8ec;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row11_col1, #T_ba5ef_row16_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row12_col1 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row13_col1 {
#   background-color: #a5cde3;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row14_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row15_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row15_col1 {
#   background-color: #abd0e6;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row16_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_ba5ef_row17_col0, #T_ba5ef_row17_col1 {
#   background-color: #f7fbff;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# </style>
# <table id="T_ba5ef" class="dataframe">
#   <caption>Average Coffee Shop Performance by District</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba5ef_level0_col0" class="col_heading level0 col0" >Average_Bayesian_Score</th>
#       <th id="T_ba5ef_level0_col1" class="col_heading level0 col1" >Average_Rating</th>
#       <th id="T_ba5ef_level0_col2" class="col_heading level0 col2" >Number_Of_Coffee_Shops</th>
#       <th id="T_ba5ef_level0_col3" class="col_heading level0 col3" >Average_Total_Reviews</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual_District_from_Spatial_Join</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba5ef_level0_row0" class="row_heading level0 row0" >Southern</th>
#       <td id="T_ba5ef_row0_col0" class="data row0 col0" >4.42</td>
#       <td id="T_ba5ef_row0_col1" class="data row0 col1" >4.55</td>
#       <td id="T_ba5ef_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_ba5ef_row0_col3" class="data row0 col3" >200</td>
#     </tr>
#     <tr>
#       <th id="T_ba5ef_level0_row1" class="row_heading level0 row1" >Central & Western</th>
#       <td id="T_ba5ef_row1_col0" class="data row1 col0" >4.33</td>
#       <td id="T_ba5ef_row1_col1" class="data row1 col1" >4.42</td>
#       <td id="T_ba5ef_row1_col2" class="data row1 col2" >55</td>
#       <td id="T_ba5ef_row1_col3" class="data row1 col3" >266</td>
#     </tr>
#     <tr>
#       <th id="T_ba5ef_level0_row2" class="row_heading level0 row2" >Eastern</th>
#       <td id="T_ba5ef_row2_col0" class="data row2 col0" >4.32</td>
#       <td id="T_ba5ef_row2_col1" class="data row2 col1" >4.53</td>
#       <td id="T_ba5ef_row2_col2" class="data row2 col2" >15</td>
#       <td id="T_ba5ef_row2_col3" class="data row2 col3" >64</td>
#     </tr>
#     <tr>
#       <th id="T_ba5ef_level0_row3" class="row_heading level0 row3" >Wan Chai</th>
#       <td id="T_ba5ef_row3_col0" class="data row3 col0" >4.29</td>
#       <td id="T_ba5ef_row3_col1" class="data row3 col1" >4.40</td>
#       <td id="T_ba5ef_row3_col2" class="data row3 col2" >51</td>
#       <td id="T_ba5ef_row3_col3" class="data row3 col3" >172</td>
#     </tr>
#     <tr>
#       <th id="T_ba5ef_level0_row4" class="row_heading level0 row4" >Yau Tsim Mong</th>
#       <td id="T_ba5ef_row4_col0" class="data row4 col0" >4.25</td>
#       <td id="T_ba5ef_row4_col1" class="data row4 col1" >4.30</td>
#       <td id="T_ba5ef_row4_col2" class="data row4 col2" >54</td>
#       <td id="T_ba5ef_row4_col3" class="data row4 col3" >258</td>
#     </tr>
#     <tr>
#       <th id="T_ba5ef_level0_row5" class="row_heading level0 row5" >Islands</th>
#       <td id="T_ba5ef_row5_col0" class="data row5 col0" >4.23</td>
#       <td id="T_ba5ef_row5_col1" class="data row5 col1" >4.26</td>
#       <td id="T_ba5ef_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_ba5ef_row5_col3" class="data row5 col3" >78</td>
#     </tr>
#     <tr>
#       <th id="T_ba5ef_level0_row6" class="row_heading level0 row6" >Sham Shui Po</th>
#       <td id="T_ba5ef_row6_col0" class="data row6 col0" >4.23</td>
#       <td id="T_ba5ef_row6_col1" class="data row6 col1" >4.34</td>
#       <td id="T_ba5ef_row6_col2" class="data row6 col2" >49</td>
#       <td id="T_ba5ef_row6_col3" class="data row6 col3" >132</td>
#     </tr>
#     <tr>
#       <th id="T_ba5ef_level0_row7" class="row_heading level0 row7" >Kwun Tong</th>
#       <td id="T_ba5ef_row7_col0" class="data row7 col0" >4.23</td>
#       <td id="T_ba5ef_row7_col1" class="data row7 col1" >4.39</td>
#       <td id="T_ba5ef_row7_col2" class="data row7 col2" >50</td>
#       <td id="T_ba5ef_row7_col3" class="data row7 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_ba5ef_level0_row8" class="row_heading level0 row8" >Tsuen Wan</th>
#       <td id="T_ba5ef_row8_col0" class="data row8 col0" >4.23</td>
#       <td id="T_ba5ef_row8_col1" class="data row8 col1" >4.32</td>
#       <td id="T_ba5ef_row8_col2" class="data row8 col2" >35</td>
#       <td id="T_ba5ef_row8_col3" class="data row8 col3" >129</td>
#     </tr>
#     <tr>
#       <th id="T_ba5ef_

# %%
# Step 4: The Map Unfolds - Visualizing Hong Kong's Coffee Landscape (cont'd)
# Coffee Shop Density by District

# Calculate and Style Coffee Shop Density by District (using new population data)
print("\n--- Calculating Coffee Shop Density by District (by Area and Population) ---")

# Load the population density data
df_pop_density = pd.read_csv('Hong_Kong_Population_Density.csv')

# Get the count of coffee shops per district from our processed data
shop_counts = df_coffeeshops.groupby('Actual_District_from_Spatial_Join').agg(
    Number_Of_Coffee_Shops=('Name', 'count')
).reset_index() # Convert index back to a column for merging
shop_counts.rename(columns={'Actual_District_from_Spatial_Join': 'District'}, inplace=True) # Rename for merging

# Merge shop counts with population and area data
density_data = shop_counts.merge(
    df_pop_density[['District', 'Total_population', 'Area']], # Select relevant columns from pop_density
    on='District',
    how='left'
)

# Handle potential NaNs if a district from coffee shops isn't in population data
density_data[['Total_population', 'Area']] = density_data[['Total_population', 'Area']].fillna(0)


# --- DENSITY CALCULATIONS ---
# Calculate: 1 coffee shop per how many people / per how many sq km

# Handle cases where Number_Of_Coffee_Shops is 0 to avoid division by zero
density_data['People_Per_Coffee_Shop'] = density_data.apply(
    lambda row: row['Total_population'] / row['Number_Of_Coffee_Shops']
    if row['Number_Of_Coffee_Shops'] > 0 else np.nan, axis=1 # Use NaN if no shops
)

density_data['Sq_Km_Per_Coffee_Shop'] = density_data.apply(
    lambda row: row['Area'] / row['Number_Of_Coffee_Shops']
    if row['Number_Of_Coffee_Shops'] > 0 else np.nan, axis=1 # Use NaN if no shops
)


density_results_people = density_data[['District','People_Per_Coffee_Shop','Number_Of_Coffee_Shops','Total_population']]
density_results_people_sorted = density_results_people.sort_values(by='People_Per_Coffee_Shop', ascending=True).copy()

density_results_area = density_data[['District','Sq_Km_Per_Coffee_Shop','Number_Of_Coffee_Shops','Area']]
density_results_area_sorted = density_results_area.sort_values(by='Sq_Km_Per_Coffee_Shop', ascending=True).copy()

# --- Styling the Density Table ---
styled_density_table_people = density_results_people_sorted.style \
    .background_gradient(subset=['People_Per_Coffee_Shop'], cmap='Blues_r') \
    .format({
        'Number_Of_Coffee_Shops': "{:,.0f}",
        'Total_population': "{:,.0f}", # Population as integer with comma
        'People_Per_Coffee_Shop': "{:,.0f}", # People per coffee shop (rounded to whole person)
    }) \
    .set_caption("Coffee Shop Density by District (People per Shop)") \
    .set_properties(**{'font-size': '11pt', 'text-align': 'center'})

styled_density_table_area = density_results_area_sorted.style \
    .background_gradient(subset=['Sq_Km_Per_Coffee_Shop'], cmap='Blues_r') \
    .format({
        'Number_Of_Coffee_Shops': "{:,.0f}",
        'Area': "{:,.2f}", # Area in km2 with 2 decimal places
        'Sq_Km_Per_Coffee_Shop': "{:,.2f}" # Sq Km per coffee shop (2 decimal places)
    }) \
    .set_caption("Coffee Shop Density by District (Area per Shop)") \
    .set_properties(**{'font-size': '11pt', 'text-align': 'center'})

print("\nCoffee Shop Density Table:")
display(styled_density_table_area)
display(styled_density_table_people)
# Out:
# --- Calculating Coffee Shop Density by District (by Area and Population) ---
#
# Coffee Shop Density Table:
# <style type="text/css">
# #T_e955f_row0_col0, #T_e955f_row0_col2, #T_e955f_row0_col3, #T_e955f_row1_col0, #T_e955f_row1_col2, #T_e955f_row1_col3, #T_e955f_row2_col0, #T_e955f_row2_col2, #T_e955f_row2_col3, #T_e955f_row3_col0, #T_e955f_row3_col2, #T_e955f_row3_col3, #T_e955f_row4_col0, #T_e955f_row4_col2, #T_e955f_row4_col3, #T_e955f_row5_col0, #T_e955f_row5_col2, #T_e955f_row5_col3, #T_e955f_row6_col0, #T_e955f_row6_col2, #T_e955f_row6_col3, #T_e955f_row7_col0, #T_e955f_row7_col2, #T_e955f_row7_col3, #T_e955f_row8_col0, #T_e955f_row8_col2, #T_e955f_row8_col3, #T_e955f_row9_col0, #T_e955f_row9_col2, #T_e955f_row9_col3, #T_e955f_row10_col0, #T_e955f_row10_col2, #T_e955f_row10_col3, #T_e955f_row11_col0, #T_e955f_row11_col2, #T_e955f_row11_col3, #T_e955f_row12_col0, #T_e955f_row12_col2, #T_e955f_row12_col3, #T_e955f_row13_col0, #T_e955f_row13_col2, #T_e955f_row13_col3, #T_e955f_row14_col0, #T_e955f_row14_col2, #T_e955f_row14_col3, #T_e955f_row15_col0, #T_e955f_row15_col2, #T_e955f_row15_col3, #T_e955f_row16_col0, #T_e955f_row16_col2, #T_e955f_row16_col3, #T_e955f_row17_col0, #T_e955f_row17_col2, #T_e955f_row17_col3 {
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row1_col1, #T_e955f_row2_col1, #T_e955f_row3_col1, #T_e955f_row4_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row5_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row6_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row7_col1 {
#   background-color: #084387;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row8_col1 {
#   background-color: #084488;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row9_col1 {
#   background-color: #084c95;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row10_col1 {
#   background-color: #084d96;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row11_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row12_col1, #T_e955f_row13_col1 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row14_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row15_col1 {
#   background-color: #a3cce3;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row16_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_e955f_row17_col1 {
#   background-color: #f7fbff;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# </style>
# <table id="T_e955f" class="dataframe">
#   <caption>Coffee Shop Density by District (Area per Shop)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e955f_level0_col0" class="col_heading level0 col0" >District</th>
#       <th id="T_e955f_level0_col1" class="col_heading level0 col1" >Sq_Km_Per_Coffee_Shop</th>
#       <th id="T_e955f_level0_col2" class="col_heading level0 col2" >Number_Of_Coffee_Shops</th>
#       <th id="T_e955f_level0_col3" class="col_heading level0 col3" >Area</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e955f_level0_row0" class="row_heading level0 row0" >16</th>
#       <td id="T_e955f_row0_col0" class="data row0 col0" >Yau Tsim Mong</td>
#       <td id="T_e955f_row0_col1" class="data row0 col1" >0.13</td>
#       <td id="T_e955f_row0_col2" class="data row0 col2" >54</td>
#       <td id="T_e955f_row0_col3" class="data row0 col3" >6.99</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_e955f_row1_col0" class="data row1 col0" >Sham Shui Po</td>
#       <td id="T_e955f_row1_col1" class="data row1 col1" >0.19</td>
#       <td id="T_e955f_row1_col2" class="data row1 col2" >49</td>
#       <td id="T_e955f_row1_col3" class="data row1 col3" >9.36</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_e955f_row2_col0" class="data row2 col0" >Wan Chai</td>
#       <td id="T_e955f_row2_col1" class="data row2 col1" >0.21</td>
#       <td id="T_e955f_row2_col2" class="data row2 col2" >51</td>
#       <td id="T_e955f_row2_col3" class="data row2 col3" >10.56</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_e955f_row3_col0" class="data row3 col0" >Kwun Tong</td>
#       <td id="T_e955f_row3_col1" class="data row3 col1" >0.23</td>
#       <td id="T_e955f_row3_col2" class="data row3 col2" >50</td>
#       <td id="T_e955f_row3_col3" class="data row3 col3" >11.28</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_e955f_row4_col0" class="data row4 col0" >Central & Western</td>
#       <td id="T_e955f_row4_col1" class="data row4 col1" >0.23</td>
#       <td id="T_e955f_row4_col2" class="data row4 col2" >55</td>
#       <td id="T_e955f_row4_col3" class="data row4 col3" >12.55</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_e955f_row5_col0" class="data row5 col0" >Kowloon City</td>
#       <td id="T_e955f_row5_col1" class="data row5 col1" >0.40</td>
#       <td id="T_e955f_row5_col2" class="data row5 col2" >25</td>
#       <td id="T_e955f_row5_col3" class="data row5 col3" >10.02</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row6" class="row_heading level0 row6" >15</th>
#       <td id="T_e955f_row6_col0" class="data row6 col0" >Wong Tai Sin</td>
#       <td id="T_e955f_row6_col1" class="data row6 col1" >1.03</td>
#       <td id="T_e955f_row6_col2" class="data row6 col2" >9</td>
#       <td id="T_e955f_row6_col3" class="data row6 col3" >9.30</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_e955f_row7_col0" class="data row7 col0" >Eastern</td>
#       <td id="T_e955f_row7_col1" class="data row7 col1" >1.20</td>
#       <td id="T_e955f_row7_col2" class="data row7 col2" >15</td>
#       <td id="T_e955f_row7_col3" class="data row7 col3" >17.99</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row8" class="row_heading level0 row8" >4</th>
#       <td id="T_e955f_row8_col0" class="data row8 col0" >Kwai Tsing</td>
#       <td id="T_e955f_row8_col1" class="data row8 col1" >1.30</td>
#       <td id="T_e955f_row8_col2" class="data row8 col2" >18</td>
#       <td id="T_e955f_row8_col3" class="data row8 col3" >23.34</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_e955f_row9_col0" class="data row9 col0" >Tsuen Wan</td>
#       <td id="T_e955f_row9_col1" class="data row9 col1" >1.77</td>
#       <td id="T_e955f_row9_col2" class="data row9 col2" >35</td>
#       <td id="T_e955f_row9_col3" class="data row9 col3" >61.94</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row10" class="row_heading level0 row10" >8</th>
#       <td id="T_e955f_row10_col0" class="data row10 col0" >Sha Tin</td>
#       <td id="T_e955f_row10_col1" class="data row10 col1" >1.81</td>
#       <td id="T_e955f_row10_col2" class="data row10 col2" >38</td>
#       <td id="T_e955f_row10_col3" class="data row10 col3" >68.72</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row11" class="row_heading level0 row11" >13</th>
#       <td id="T_e955f_row11_col0" class="data row11 col0" >Tuen Mun</td>
#       <td id="T_e955f_row11_col1" class="data row11 col1" >2.68</td>
#       <td id="T_e955f_row11_col2" class="data row11 col2" >32</td>
#       <td id="T_e955f_row11_col3" class="data row11 col3" >85.80</td>
#     </tr>
#     <tr>
#       <th id="T_e955f_level0_row12" class="row_heading level0 row12" >17</th>
#       <td id="T_e955f_row12_col0" class="data row12 col0" >Yuen Long</td>
#       <td id="T_e955f_row12_col1"
# <style type="text/css">
# #T_0f9c3_row0_col0, #T_0f9c3_row0_col2, #T_0f9c3_row0_col3, #T_0f9c3_row1_col0, #T_0f9c3_row1_col2, #T_0f9c3_row1_col3, #T_0f9c3_row2_col0, #T_0f9c3_row2_col2, #T_0f9c3_row2_col3, #T_0f9c3_row3_col0, #T_0f9c3_row3_col2, #T_0f9c3_row3_col3, #T_0f9c3_row4_col0, #T_0f9c3_row4_col2, #T_0f9c3_row4_col3, #T_0f9c3_row5_col0, #T_0f9c3_row5_col2, #T_0f9c3_row5_col3, #T_0f9c3_row6_col0, #T_0f9c3_row6_col2, #T_0f9c3_row6_col3, #T_0f9c3_row7_col0, #T_0f9c3_row7_col2, #T_0f9c3_row7_col3, #T_0f9c3_row8_col0, #T_0f9c3_row8_col2, #T_0f9c3_row8_col3, #T_0f9c3_row9_col0, #T_0f9c3_row9_col2, #T_0f9c3_row9_col3, #T_0f9c3_row10_col0, #T_0f9c3_row10_col2, #T_0f9c3_row10_col3, #T_0f9c3_row11_col0, #T_0f9c3_row11_col2, #T_0f9c3_row11_col3, #T_0f9c3_row12_col0, #T_0f9c3_row12_col2, #T_0f9c3_row12_col3, #T_0f9c3_row13_col0, #T_0f9c3_row13_col2, #T_0f9c3_row13_col3, #T_0f9c3_row14_col0, #T_0f9c3_row14_col2, #T_0f9c3_row14_col3, #T_0f9c3_row15_col0, #T_0f9c3_row15_col2, #T_0f9c3_row15_col3, #T_0f9c3_row16_col0, #T_0f9c3_row16_col2, #T_0f9c3_row16_col3, #T_0f9c3_row17_col0, #T_0f9c3_row17_col2, #T_0f9c3_row17_col3 {
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row1_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row2_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row3_col1 {
#   background-color: #08478d;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row4_col1 {
#   background-color: #084990;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row5_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row6_col1 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row7_col1 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row8_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row9_col1 {
#   background-color: #1764ab;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row10_col1, #T_0f9c3_row11_col1 {
#   background-color: #1966ad;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row12_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row13_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row14_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row15_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row16_col1 {
#   background-color: #add0e6;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# #T_0f9c3_row17_col1 {
#   background-color: #f7fbff;
#   color: #000000;
#   font-size: 11pt;
#   text-align: center;
# }
# </style>
# <table id="T_0f9c3" class="dataframe">
#   <caption>Coffee Shop Density by District (People per Shop)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f9c3_level0_col0" class="col_heading level0 col0" >District</th>
#       <th id="T_0f9c3_level0_col1" class="col_heading level0 col1" >People_Per_Coffee_Shop</th>
#       <th id="T_0f9c3_level0_col2" class="col_heading level0 col2" >Number_Of_Coffee_Shops</th>
#       <th id="T_0f9c3_level0_col3" class="col_heading level0 col3" >Total_population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f9c3_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_0f9c3_row0_col0" class="data row0 col0" >Wan Chai</td>
#       <td id="T_0f9c3_row0_col1" class="data row0 col1" >3,269</td>
#       <td id="T_0f9c3_row0_col2" class="data row0 col2" >51</td>
#       <td id="T_0f9c3_row0_col3" class="data row0 col3" >166,695</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_0f9c3_row1_col0" class="data row1 col0" >Central & Western</td>
#       <td id="T_0f9c3_row1_col1" class="data row1 col1" >4,290</td>
#       <td id="T_0f9c3_row1_col2" class="data row1 col2" >55</td>
#       <td id="T_0f9c3_row1_col3" class="data row1 col3" >235,953</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row2" class="row_heading level0 row2" >16</th>
#       <td id="T_0f9c3_row2_col0" class="data row2 col0" >Yau Tsim Mong</td>
#       <td id="T_0f9c3_row2_col1" class="data row2 col1" >5,753</td>
#       <td id="T_0f9c3_row2_col2" class="data row2 col2" >54</td>
#       <td id="T_0f9c3_row2_col3" class="data row2 col3" >310,647</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_0f9c3_row3_col0" class="data row3 col0" >Sham Shui Po</td>
#       <td id="T_0f9c3_row3_col1" class="data row3 col1" >8,798</td>
#       <td id="T_0f9c3_row3_col2" class="data row3 col2" >49</td>
#       <td id="T_0f9c3_row3_col3" class="data row3 col3" >431,090</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_0f9c3_row4_col0" class="data row4 col0" >Tsuen Wan</td>
#       <td id="T_0f9c3_row4_col1" class="data row4 col1" >9,146</td>
#       <td id="T_0f9c3_row4_col2" class="data row4 col2" >35</td>
#       <td id="T_0f9c3_row4_col3" class="data row4 col3" >320,094</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_0f9c3_row5_col0" class="data row5 col0" >Islands</td>
#       <td id="T_0f9c3_row5_col1" class="data row5 col1" >10,899</td>
#       <td id="T_0f9c3_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_0f9c3_row5_col3" class="data row5 col3" >185,282</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_0f9c3_row6_col0" class="data row6 col0" >Sai Kung</td>
#       <td id="T_0f9c3_row6_col1" class="data row6 col1" >12,869</td>
#       <td id="T_0f9c3_row6_col2" class="data row6 col2" >38</td>
#       <td id="T_0f9c3_row6_col3" class="data row6 col3" >489,037</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row7" class="row_heading level0 row7" >5</th>
#       <td id="T_0f9c3_row7_col0" class="data row7 col0" >Kwun Tong</td>
#       <td id="T_0f9c3_row7_col1" class="data row7 col1" >13,463</td>
#       <td id="T_0f9c3_row7_col2" class="data row7 col2" >50</td>
#       <td id="T_0f9c3_row7_col3" class="data row7 col3" >673,166</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_0f9c3_row8_col0" class="data row8 col0" >Tai Po</td>
#       <td id="T_0f9c3_row8_col1" class="data row8 col1" >13,760</td>
#       <td id="T_0f9c3_row8_col2" class="data row8 col2" >23</td>
#       <td id="T_0f9c3_row8_col3" class="data row8 col3" >316,470</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row9" class="row_heading level0 row9" >13</th>
#       <td id="T_0f9c3_row9_col0" class="data row9 col0" >Tuen Mun</td>
#       <td id="T_0f9c3_row9_col1" class="data row9 col1" >15,840</td>
#       <td id="T_0f9c3_row9_col2" class="data row9 col2" >32</td>
#       <td id="T_0f9c3_row9_col3" class="data row9 col3" >506,879</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row10" class="row_heading level0 row10" >17</th>
#       <td id="T_0f9c3_row10_col0" class="data row10 col0" >Yuen Long</td>
#       <td id="T_0f9c3_row10_col1" class="data row10 col1" >16,295</td>
#       <td id="T_0f9c3_row10_col2" class="data row10 col2" >41</td>
#       <td id="T_0f9c3_row10_col3" class="data row10 col3" >668,080</td>
#     </tr>
#     <tr>
#       <th id="T_0f9c3_level0_row11" class="row_heading level0 row11" >3</th>
#       <td id="T_0f9c3_row11_col0" class="data row11 col0" >Kowloon City</td>
#       <td id="T_0f9c3_row11_col1" class="data row11 col1" >16,425</td>
#       <td id="

# %%
# Step 4: The Map Unfolds - Visualizing Hong Kong's Coffee Landscape
# Interactive map of HK specialty coffee shops

import folium
from folium.plugins import MarkerCluster
import pandas as pd

BAYESIAN_M_VALUE = 100 # Ensure this matches the 'm' used in your calculation

HK_CENTER_LAT = 22.3193
HK_CENTER_LON = 114.1694
INITIAL_MAP_ZOOM = 12

# --- Create the Interactive Map ---
print("\n--- Generating Interactive Map ---")

# Create the base map
m = folium.Map(location=[HK_CENTER_LAT, HK_CENTER_LON], zoom_start=INITIAL_MAP_ZOOM,
               tiles='CartoDB positron')

# Create a MarkerCluster for better visualization of many points
marker_cluster = MarkerCluster().add_to(m)

print("Adding coffee shop markers to the map...")
# Loop through the DataFrame to add markers
for index, row in df_coffeeshops.iterrows():
    lat = row['Latitude']
    lon = row['Longitude']
    name = row['Name']
    rating = row['Rating']
    total_reviews = row['Total Reviews']
    bayesian_score = row['Bayesian_Weighted_Rating']
    # Use the actual district from the cleaned data (using .get() for safety)
    actual_district = row.get('Actual_District_from_Spatial_Join', 'N/A')

    # Create popup text
    popup_text = f"""
    <b>{name}</b><br>
    **Actual District:** {actual_district}<br>
    Rating: {rating:.1f} ({total_reviews} reviews)<br>
    Bayes Score (m={BAYESIAN_M_VALUE}): {bayesian_score:.2f}<br>
    Address: {row['Address']}
    """

    # Customize marker color based on Bayesian Score
    if bayesian_score >= 4.5:
        marker_color = 'green'
    elif bayesian_score >= 4.0:
        marker_color = 'blue'
    elif bayesian_score >= 3.5:
        marker_color = 'orange'
    else:
        marker_color = 'red'

    folium.Marker(
        location=[lat, lon],
        popup=folium.Popup(popup_text, max_width=300),
        tooltip=f"{name} ({rating:.1f} stars in {actual_district})",
        icon=folium.Icon(color=marker_color, icon='coffee', prefix='fa')
    ).add_to(marker_cluster)

# Add a Layer Control to toggle districts on/off (optional, but good for interactive maps)
folium.LayerControl().add_to(m)

print("\nMap created. Displaying map in Colab output.")
# Display the map in Colab
m
# Out:
# --- Generating Interactive Map ---
# Adding coffee shop markers to the map...
#
# Map created. Displaying map in Colab output.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85dc1b47302153e438a95101ba13b785 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85dc1b47302153e438a95101ba13b785&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85dc1b47302153e438a95101ba13b785 = L.map(
#                 &quot;map_85dc1b47302153e438a95101ba13b785&quot;,
#                 {
#                     center: [22.3193, 114.1694],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f82e2ca26d937ea8e7ec07fdec1faf3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f82e2ca26d937ea8e7ec07fdec1faf3.addTo(map_85dc1b47302153e438a95101ba13b785);
#
#
#             var marker_cluster_46fd3ad9a74f2a4fbdbad2b0a61417d2 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_94e8908fae3bcf36c84e6dabacb4b44b = L.marker(
#                 [22.283944, 114.1555478],
#                 {
# }
#             ).addTo(marker_cluster_46fd3ad9a74f2a4fbdbad2b0a61417d2);
#
#
#             var icon_1cd7c752c73961d1da05b67366ad90dc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;coffee&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_14a9d56225e8551460fdc4e9b486178a = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_081ed62398d7f41fbad6e6136fd05c50 = $(`&lt;div id=&quot;html_081ed62398d7f41fbad6e6136fd05c50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Chart Coffee (Central Market)&lt;/b&gt;&lt;br&gt;     **Actual District:** Central &amp; Western&lt;br&gt;     Rating: 4.8 (440 reviews)&lt;br&gt;     Bayes Score (m=100): 4.69&lt;br&gt;     Address: Shop 218, 2/F, Central Market, 93 Queen&#x27;s Road Central, Central, Hong Kong     &lt;/div&gt;`)[0];
#                 popup_14a9d56225e8551460fdc4e9b486178a.setContent(html_081ed62398d7f41fbad6e6136fd05c50);
#
#
#
#         marker_94e8908fae3bcf36c84e6dabacb4b44b.bindPopup(popup_14a9d56225e8551460fdc4e9b486178a)
#         ;
#
#
#
#
#             marker_94e8908fae3bcf36c84e6dabacb4b44b.bindTooltip(
#                 `&lt;div&gt;
#                      Chart Coffee (Central Market) (4.8 stars in Central &amp; Western)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_94e8908fae3bcf36c84e6dabacb4b44b.setIcon(icon_1cd7c752c73961d1da05b67366ad90dc);
#
#
#             var marker_67ff3e7a20f7a0194f9fe5896a3d2b04 = L.marker(
#                 [22.3614854, 114.1325091],
#                 {
# }
#             ).addTo(marker_cluster_46fd3ad9a74f2a4fbdbad2b0a61417d2);
#
#
#             var icon_d30c1da6c5d935d0cb289c5d2b0d9d71 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;coffee&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8a04278cb767495817805d2f0bb56c7b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_b47ff949df3fd6f50490768a8ac97800 = $(`&lt;div id=&quot;html_b47ff949df3fd6f50490768a8ac97800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Chart Coffee (KCC)&lt;/b&gt;&lt;br&gt;     **Actual District:** Kwai Tsing&lt;br&gt;     Rating: 5.0 (93 reviews)&lt;br&gt;     Bayes Score (m=100): 4.59&lt;br&gt;     Address: Shop 202, Joy@Kowloon Commerce Centre, 51 Kwai Cheong Rd, Kwai Chung, Hong Kong     &lt;/div&gt;`)[0];
#                 popup_8a04278cb767495817805d2f0bb56c7b.setContent(html_b47ff949df3fd6f50490768a8ac97800);
#
#
#
#         marker_67ff3e7a20f7a0194f9fe5896a3d2b04.bindPopup(pop

# %%
# Save the map as an HTML file
map_filename = 'hong_kong_coffee_shops_map.html'
m.save(map_filename)
print(f"Map saved to {map_filename}")
# Out:
# Map saved to hong_kong_coffee_shops_map.html
